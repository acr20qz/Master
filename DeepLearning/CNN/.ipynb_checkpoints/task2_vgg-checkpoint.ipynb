# %%
#加载第一张图片
from keras.preprocessing.image import load_img, img_to_array
pic1 = '1.png'
pic1 = load_img(pic1,target_size=(224,224))
print(pic1)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x211A4715730>

# %%
#可视化
from matplotlib import pyplot as plt
fig1 = plt.figure()
plt.imshow(pic1)

# %%
#图片格式转数组格式
pic1 = img_to_array(pic1)
print(type(pic1))
print(pic1.shape)
# Out:
# <class 'numpy.ndarray'>
# (224, 224, 3)

# %%
#数据预处理
from keras.applications.vgg16 import preprocess_input
import numpy as np
x = np.expand_dims(pic1,axis=0)
x = preprocess_input(x)
print(x.shape)
# Out:
# (1, 224, 224, 3)

# %%
#图像核心特征提取
from keras.applications.vgg16 import VGG16
model_vgg = VGG16(weights='imagenet',include_top=False)
features = model_vgg.predict(x)
print(features.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 53s 1us/step
# 58900480/58889256 [==============================] - 53s 1us/step
# (1, 7, 7, 512)

# %%
print(features)
# Out:
# [[[[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    ...
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 2.8832979e+01]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 5.2411633e+01]]
#
#   [[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 9.4602652e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 5.1430378e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    ...
#    [1.8990492e+02 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [9.1413719e+01 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 2.3506334e+00
#     0.0000000e+00 5.7827114e+01]]
#
#   [[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     8.4295197e+00 1.4058911e+01]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     1.1306167e+00 1.9081318e+01]
#    [7.5548584e+01 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    ...
#    [3.9374457e+02 0.0000000e+00 0.0000000e+00 ... 1.1898787e+01
#     0.0000000e+00 0.0000000e+00]
#    [3.0349246e+02 0.0000000e+00 2.9792597e+01 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 5.6491573e+01]]
#
#   ...
#
#   [[0.0000000e+00 0.0000000e+00 2.9288855e+01 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [6.6649313e+00 0.0000000e+00 4.9684157e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    ...
#    [0.0000000e+00 0.0000000e+00 2.7636688e+01 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.2391959e+01
#     0.0000000e+00 3.5788097e+01]]
#
#   [[0.0000000e+00 0.0000000e+00 7.4556069e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [2.4487019e-01 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    ...
#    [0.0000000e+00 0.0000000e+00 4.2404926e+01 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 2.3084120e+01 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 1.4054592e+01
#     0.0000000e+00 0.0000000e+00]]
#
#   [[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    ...
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]
#    [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#     0.0000000e+00 0.0000000e+00]]]]

# %%
#flatten展开
features = features.reshape(1,7*7*512)
print(features.shape)
# Out:
# (1, 25088)

# %%
#load image and preprocess it with vgg16 structure
#--by flare
from keras.preprocessing.image import img_to_array,load_img
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
import numpy as np

model_vgg = VGG16(weights='imagenet', include_top=False)
#define a method to load and preprocess the image
def modelProcess(img_path,model):
    img = load_img(img_path, target_size=(224, 224))
    img = img_to_array(img)
    x = np.expand_dims(img,axis=0)
    x = preprocess_input(x)
    x_vgg = model.predict(x)
    x_vgg = x_vgg.reshape(1,25088)
    return x_vgg
#list file names of the training datasets
import os
folder = "task2_data/cats"
dirs = os.listdir(folder)
#generate path for the images
img_path = []
for i in dirs:                             
    if os.path.splitext(i)[1] == ".jpg":   
        img_path.append(i)
img_path = [folder+"//"+i for i in img_path]

#preprocess multiple images
features1 = np.zeros([len(img_path),25088])
for i in range(len(img_path)):
    feature_i = modelProcess(img_path[i],model_vgg)
    print('preprocessed:',img_path[i])
    features1[i] = feature_i
    
folder = "task2_data/dogs"
dirs = os.listdir(folder)
img_path = []
for i in dirs:                             
    if os.path.splitext(i)[1] == ".jpg":   
        img_path.append(i)
img_path = [folder+"//"+i for i in img_path]
features2 = np.zeros([len(img_path),25088])
for i in range(len(img_path)):
    feature_i = modelProcess(img_path[i],model_vgg)
    print('preprocessed:',img_path[i])
    features2[i] = feature_i
    
#label the results
print(features1.shape,features2.shape)
y1 = np.zeros(300)
y2 = np.ones(300)

#generate the training data
X = np.concatenate((features1,features2),axis=0)
y = np.concatenate((y1,y2),axis=0)
y = y.reshape(-1,1)
print(X.shape,y.shape)
# Out:
# preprocessed: task2_data/cats//cats_1.jpg
# preprocessed: task2_data/cats//cats_10.jpg
# preprocessed: task2_data/cats//cats_100.jpg
# preprocessed: task2_data/cats//cats_101.jpg
# preprocessed: task2_data/cats//cats_102.jpg
# preprocessed: task2_data/cats//cats_103.jpg
# preprocessed: task2_data/cats//cats_104.jpg
# preprocessed: task2_data/cats//cats_105.jpg
# preprocessed: task2_data/cats//cats_106.jpg
# preprocessed: task2_data/cats//cats_107.jpg
# preprocessed: task2_data/cats//cats_108.jpg
# preprocessed: task2_data/cats//cats_109.jpg
# preprocessed: task2_data/cats//cats_11.jpg
# preprocessed: task2_data/cats//cats_110.jpg
# preprocessed: task2_data/cats//cats_111.jpg
# preprocessed: task2_data/cats//cats_112.jpg
# preprocessed: task2_data/cats//cats_113.jpg
# preprocessed: task2_data/cats//cats_114.jpg
# preprocessed: task2_data/cats//cats_115.jpg
# preprocessed: task2_data/cats//cats_116.jpg
# preprocessed: task2_data/cats//cats_117.jpg
# preprocessed: task2_data/cats//cats_118.jpg
# preprocessed: task2_data/cats//cats_119.jpg
# preprocessed: task2_data/cats//cats_12.jpg
# preprocessed: task2_data/cats//cats_120.jpg
# preprocessed: task2_data/cats//cats_121.jpg
# preprocessed: task2_data/cats//cats_122.jpg
# preprocessed: task2_data/cats//cats_123.jpg
# preprocessed: task2_data/cats//cats_124.jpg
# preprocessed: task2_data/cats//cats_125.jpg
# preprocessed: task2_data/cats//cats_126.jpg
# preprocessed: task2_data/cats//cats_127.jpg
# preprocessed: task2_data/cats//cats_128.jpg
# preprocessed: task2_data/cats//cats_129.jpg
# preprocessed: task2_data/cats//cats_13.jpg
# preprocessed: task2_data/cats//cats_130.jpg
# preprocessed: task2_data/cats//cats_131.jpg
# preprocessed: task2_data/cats//cats_132.jpg
# preprocessed: task2_data/cats//cats_133.jpg
# preprocessed: task2_data/cats//cats_134.jpg
# preprocessed: task2_data/cats//cats_135.jpg
# preprocessed: task2_data/cats//cats_136.jpg
# preprocessed: task2_data/cats//cats_137.jpg
# preprocessed: task2_data/cats//cats_138.jpg
# preprocessed: task2_data/cats//cats_139.jpg
# preprocessed: task2_data/cats//cats_14.jpg
# preprocessed: task2_data/cats//cats_140.jpg
# preprocessed: task2_data/cats//cats_141.jpg
# preprocessed: task2_data/cats//cats_142.jpg
# preprocessed: task2_data/cats//cats_143.jpg
# preprocessed: task2_data/cats//cats_144.jpg
# preprocessed: task2_data/cats//cats_145.jpg
# preprocessed: task2_data/cats//cats_146.jpg
# preprocessed: task2_data/cats//cats_147.jpg
# preprocessed: task2_data/cats//cats_148.jpg
# preprocessed: task2_data/cats//cats_149.jpg
# preprocessed: task2_data/cats//cats_15.jpg
# preprocessed: task2_data/cats//cats_150.jpg
# preprocessed: task2_data/cats//cats_151.jpg
# preprocessed: task2_data/cats//cats_152.jpg
# preprocessed: task2_data/cats//cats_153.jpg
# preprocessed: task2_data/cats//cats_154.jpg
# preprocessed: task2_data/cats//cats_155.jpg
# preprocessed: task2_data/cats//cats_156.jpg
# preprocessed: task2_data/cats//cats_157.jpg
# preprocessed: task2_data/cats//cats_158.jpg
# preprocessed: task2_data/cats//cats_159.jpg
# preprocessed: task2_data/cats//cats_16.jpg
# preprocessed: task2_data/cats//cats_160.jpg
# preprocessed: task2_data/cats//cats_161.jpg
# preprocessed: task2_data/cats//cats_162.jpg
# preprocessed: task2_data/cats//cats_163.jpg
# preprocessed: task2_data/cats//cats_164.jpg
# preprocessed: task2_data/cats//cats_165.jpg
# preprocessed: task2_data/cats//cats_166.jpg
# preprocessed: task2_data/cats//cats_167.jpg
# preprocessed: task2_data/cats//cats_168.jpg
# preprocessed: task2_data/cats//cats_169.jpg
# preprocessed: task2_data/cats//cats_17.jpg
# preprocessed: task2_data/cats//cats_170.jpg
# preprocessed: task2_data/cats//cats_171.jpg
# preprocessed: task2_data/cats//cats_172.jpg
# preprocessed: task2_data/cats//cats_173.jpg
# preprocessed: task2_data/cats//cats_174.jpg
# preprocessed: task2_data/cats//cats_175.jpg
# preprocessed: task2_data/cats//cats_176.jpg
# preprocessed: task2_data/cats//cats_177.jpg
# preprocessed: task2_data/cats//cats_178.jpg
# preprocessed: task2_data/cats//cats_179.jpg
# preprocessed: task2_data/cats//cats_18.jpg
# preprocessed: task2_data/cats//cats_180.jpg
# preprocessed: task2_data/cats//cats_181.jpg
# preprocessed: task2_data/cats//cats_182.jpg
# preprocessed: task2_data/cats//cats_183.jpg
# preprocessed: task2_data/cats//cats_184.jpg
# preprocessed: task2_data/cats//cats_185.jpg
# preprocessed: task2_data/cats//cats_186.jpg
# preprocessed: task2_data/cats//cats_187.jpg
# preprocessed: task2_data/cats//cats_188.jpg
# preprocessed: task2_data/cats//cats_189.jpg
# preprocessed: task2_data/cats//cats_19.jpg
# preprocessed: task2_data/cats//cats_190.jpg
# preprocessed: task2_data/cats//cats_191.jpg
# preprocessed: task2_data/cats//cats_192.jpg
# preprocessed: task2_data/cats//cats_193.jpg
# preprocessed: task2_data/cats//cats_194.jpg
# preprocessed: task2_data/cats//cats_195.jpg
# preprocessed: task2_data/cats//cats_196.jpg
# preprocessed: task2_data/cats//cats_197.jpg
# preprocessed: task2_data/cats//cats_198.jpg
# preprocessed: task2_data/cats//cats_199.jpg
# preprocessed: task2_data/cats//cats_2.jpg
# preprocessed: task2_data/cats//cats_20.jpg
# preprocessed: task2_data/cats//cats_200.jpg
# preprocessed: task2_data/cats//cats_201.jpg
# preprocessed: task2_data/cats//cats_202.jpg
# preprocessed: task2_data/cats//cats_203.jpg
# preprocessed: task2_data/cats//cats_204.jpg
# preprocessed: task2_data/cats//cats_205.jpg
# preprocessed: task2_data/cats//cats_206.jpg
# preprocessed: task2_data/cats//cats_207.jpg
# preprocessed: task2_data/cats//cats_208.jpg
# preprocessed: task2_data/cats//cats_209.jpg
# preprocessed: task2_data/cats//cats_21.jpg
# preprocessed: task2_data/cats//cats_210.jpg
# preprocessed: task2_data/cats//cats_211.jpg
# preprocessed: task2_data/cats//cats_212.jpg
# preprocessed: task2_data/cats//cats_213.jpg
# preprocessed: task2_data/cats//cats_214.jpg
# preprocessed: task2_data/cats//cats_215.jpg
# preprocessed: task2_data/cats//cats_216.jpg
# preprocessed: task2_data/cats//cats_217.jpg
# preprocessed: task2_data/cats//cats_218.jpg
# preprocessed: task2_data/cats//cats_219.jpg
# preprocessed: task2_data/cats//cats_22.jpg
# preprocessed: task2_data/cats//cats_220.jpg
# preprocessed: task2_data/cats//cats_221.jpg
# preprocessed: task2_data/cats//cats_222.jpg
# preprocessed: task2_data/cats//cats_223.jpg
# preprocessed: task2_data/cats//cats_224.jpg
# preprocessed: task2_data/cats//cats_225.jpg
# preprocessed: task2_data/cats//cats_226.jpg
# preprocessed: task2_data/cats//cats_227.jpg
# preprocessed: task2_data/cats//cats_228.jpg
# preprocessed: task2_data/cats//cats_229.jpg
# preprocessed: task2_data/cats//cats_23.jpg
# preprocessed: task2_data/cats//cats_230.jpg
# preprocessed: task2_data/cats//cats_231.jpg
# preprocessed: task2_data/cats//cats_232.jpg
# preprocessed: task2_data/cats//cats_233.jpg
# preprocessed: task2_data/cats//cats_234.jpg
# preprocessed: task2_data/cats//cats_235.jpg
# preprocessed: task2_data/cats//cats_236.jpg
# preprocessed: task2_data/cats//cats_237.jpg
# preprocessed: task2_data/cats//cats_238.jpg
# preprocessed: task2_data/cats//cats_239.jpg
# preprocessed: task2_data/cats//cats_24.jpg
# preprocessed: task2_data/cats//cats_240.jpg
# preprocessed: task2_data/cats//cats_241.jpg
# preprocessed: task2_data/cats//cats_242.jpg
# preprocessed: task2_data/cats//cats_243.jpg
# preprocessed: task2_data/cats//cats_244.jpg
# preprocessed: task2_data/cats//cats_245.jpg
# preprocessed: task2_data/cats//cats_246.jpg
# preprocessed: task2_data/cats//cats_247.jpg
# preprocessed: task2_data/cats//cats_248.jpg
# preprocessed: task2_data/cats//cats_249.jpg
# preprocessed: task2_data/cats//cats_25.jpg
# preprocessed: task2_data/cats//cats_250.jpg
# preprocessed: task2_data/cats//cats_251.jpg
# preprocessed: task2_data/cats//cats_252.jpg
# preprocessed: task2_data/cats//cats_253.jpg
# preprocessed: task2_data/cats//cats_254.jpg
# preprocessed: task2_data/cats//cats_255.jpg
# preprocessed: task2_data/cats//cats_256.jpg
# preprocessed: task2_data/cats//cats_257.jpg
# preprocessed: task2_data/cats//cats_258.jpg
# preprocessed: task2_data/cats//cats_259.jpg
# preprocessed: task2_data/cats//cats_26.jpg
# preprocessed: task2_data/cats//cats_260.jpg
# preprocessed: task2_data/cats//cats_261.jpg
# preprocessed: task2_data/cats//cats_262.jpg
# preprocessed: task2_data/cats//cats_263.jpg
# preprocessed: task2_data/cats//cats_264.jpg
# preprocessed: task2_data/cats//cats_265.jpg
# preprocessed: task2_data/cats//cats_266.jpg
# preprocessed: task2_data/cats//cats_267.jpg
# preprocessed: task2_data/cats//cats_268.jpg
# preprocessed: task2_data/cats//cats_269.jpg
# preprocessed: task2_data/cats//cats_27.jpg
# preprocessed: task2_data/cats//cats_270.jpg
# preprocessed: task2_data/cats//cats_271.jpg
# preprocessed: task2_data/cats//cats_272.jpg
# preprocessed: task2_data/cats//cats_273.jpg
# preprocessed: task2_data/cats//cats_274.jpg
# preprocessed: task2_data/cats//cats_275.jpg
# preprocessed: task2_data/cats//cats_276.jpg
# preprocessed: task2_data/cats//cats_277.jpg
# preprocessed: task2_data/cats//cats_278.jpg
# preprocessed: task2_data/cats//cats_279.jpg
# preprocessed: task2_data/cats//cats_28.jpg
# preprocessed: task2_data/cats//cats_280.jpg
# preprocessed: task2_data/cats//cats_281.jpg
# preprocessed: task2_data/cats//cats_282.jpg
# preprocessed: task2_data/cats//cats_283.jpg
# preprocessed: task2_data/cats//cats_284.jpg
# preprocessed: task2_data/cats//cats_285.jpg
# preprocessed: task2_data/cats//cats_286.jpg
# preprocessed: task2_data/cats//cats_287.jpg
# preprocessed: task2_data/cats//cats_288.jpg
# preprocessed: task2_data/cats//cats_289.jpg
# preprocessed: task2_data/cats//cats_29.jpg
# preprocessed: task2_data/cats//cats_290.jpg
# preprocessed: task2_data/cats//cats_291.jpg
# preprocessed: task2_data/cats//cats_292.jpg
# preprocessed: task2_data/cats//cats_293.jpg
# preprocessed: task2_data/cats//cats_294.jpg
# preprocessed: task2_data/cats//cats_295.jpg
# preprocessed: task2_data/cats//cats_296.jpg
# preprocessed: task2_data/cats//cats_297.jpg
# preprocessed: task2_data/cats//cats_298.jpg
# preprocessed: task2_data/cats//cats_299.jpg
# preprocessed: task2_data/cats//cats_3.jpg
# preprocessed: task2_data/cats//cats_30.jpg
# preprocessed: task2_data/cats//cats_300.jpg
# preprocessed: task2_data/cats//cats_31.jpg
# preprocessed: task2_data/cats//cats_32.jpg
# preprocessed: task2_data/cats//cats_33.jpg
# preprocessed: task2_data/cats//cats_34.jpg
# preprocessed: task2_data/cats//cats_35.jpg
# preprocessed: task2_data/cats//cats_36.jpg
# preprocessed: task2_data/cats//cats_37.jpg
# preprocessed: task2_data/cats//cats_38.jpg
# preprocessed: task2_data/cats//cats_39.jpg
# preprocessed: task2_data/cats//cats_4.jpg
# preprocessed: task2_data/cats//cats_40.jpg
# preprocessed: task2_data/cats//cats_41.jpg
# preprocessed: task2_data/cats//cats_42.jpg
# preprocessed: task2_data/cats//cats_43.jpg
# preprocessed: task2_data/cats//cats_44.jpg
# preprocessed: task2_data/cats//cats_45.jpg
# preprocessed: task2_data/cats//cats_46.jpg
# preprocessed: task2_data/cats//cats_47.jpg
# preprocessed: task2_data/cats//cats_48.jpg
# preprocessed: task2_data/cats//cats_49.jpg
# preprocessed: task2_data/cats//cats_5.jpg
# preprocessed: task2_data/cats//cats_50.jpg
# preprocessed: task2_data/cats//cats_51.jpg
# preprocessed: task2_data/cats//cats_52.jpg
# preprocessed: task2_data/cats//cats_53.jpg
# preprocessed: task2_data/cats//cats_54.jpg
# preprocessed: task2_data/cats//cats_55.jpg
# preprocessed: task2_data/cats//cats_56.jpg
# preprocessed: task2_data/cats//cats_57.jpg
# preprocessed: task2_data/cats//cats_58.jpg
# preprocessed: task2_data/cats//cats_59.jpg
# preprocessed: task2_data/cats//cats_6.jpg
# preprocessed: task2_data/cats//cats_60.jpg
# preprocessed: task2_data/cats//cats_61.jpg
# preprocessed: task2_data/cats//cats_62.jpg
# preprocessed: task2_data/cats//cats_63.jpg
# preprocessed: task2_data/cats//cats_64.jpg
# preprocessed: task2_data/cats//cats_65.jpg
# preprocessed: task2_data/cats//cats_66.jpg
# preprocessed: task2_data/cats//cats_67.jpg
# preprocessed: task2_data/cats//cats_68.jpg
# preprocessed: task2_data/cats//cats_69.jpg
# preprocessed: task2_data/cats//cats_7.jpg
# preprocessed: task2_data/cats//cats_70.jpg
# preprocessed: task2_data/cats//cats_71.jpg
# preprocessed: task2_data/cats//cats_72.jpg
# preprocessed: task2_data/cats//cats_73.jpg
# preprocessed: task2_data/cats//cats_74.jpg
# preprocessed: task2_data/cats//cats_75.jpg
# preprocessed: task2_data/cats//cats_76.jpg
# preprocessed: task2_data/cats//cats_77.jpg
# preprocessed: task2_data/cats//cats_78.jpg
# preprocessed: task2_data/cats//cats_79.jpg
# preprocessed: task2_data/cats//cats_8.jpg
# preprocessed: task2_data/cats//cats_80.jpg
# preprocessed: task2_data/cats//cats_81.jpg
# preprocessed: task2_data/cats//cats_82.jpg
# preprocessed: task2_data/cats//cats_83.jpg
# preprocessed: task2_data/cats//cats_84.jpg
# preprocessed: task2_data/cats//cats_85.jpg
# preprocessed: task2_data/cats//cats_86.jpg
# preprocessed: task2_data/cats//cats_87.jpg
# preprocessed: task2_data/cats//cats_88.jpg
# preprocessed: task2_data/cats//cats_89.jpg
# preprocessed: task2_data/cats//cats_9.jpg
# preprocessed: task2_data/cats//cats_90.jpg
# preprocessed: task2_data/cats//cats_91.jpg
# preprocessed: task2_data/cats//cats_92.jpg
# preprocessed: task2_data/cats//cats_93.jpg
# preprocessed: task2_data/cats//cats_94.jpg
# preprocessed: task2_data/cats//cats_95.jpg
# preprocessed: task2_data/cats//cats_96.jpg
# preprocessed: task2_data/cats//cats_97.jpg
# preprocessed: task2_data/cats//cats_98.jpg
# preprocessed: task2_data/cats//cats_99.jpg
# preprocessed: task2_data/dogs//dogs_1.jpg
# preprocessed: task2_data/dogs//dogs_10.jpg
# preprocessed: task2_data/dogs//dogs_100.jpg
# preprocessed: task2_data/dogs//dogs_101.jpg
# preprocessed: task2_data/dogs//dogs_102.jpg
# preprocessed: task2_data/dogs//dogs_103.jpg
# preprocessed: task2_data/dogs//dogs_104.jpg
# preprocessed: task2_data/dogs//dogs_105.jpg
# preprocessed: task2_data/dogs//dogs_106.jpg
# preprocessed: task2_data/dogs//dogs_107.jpg
# preprocessed: task2_data/dogs//dogs_108.jpg
# preprocessed: task2_data/dogs//dogs_109.jpg
# preprocessed: task2_data/dogs//dogs_11.jpg
# preprocessed: task2_data/dogs//dogs_110.jpg
# preprocessed: task2_data/dogs//dogs_111.jpg
# preprocessed: task2_data/dogs//dogs_112.jpg
# preprocessed: task2_data/dogs//dogs_113.jpg
# preprocessed: task2_data/dogs//dogs_114.jpg
# preprocessed: task2_data/dogs//dogs_115.jpg
# preprocessed: task2_data/dogs//dogs_116.jpg
# preprocessed: task2_data/dogs//dogs_117.jpg
# preprocessed: task2_data/dogs//dogs_118.jpg
# preprocessed: task2_data/dogs//dogs_119.jpg
# preprocessed: task2_data/dogs//dogs_12.jpg
# preprocessed: task2_data/dogs//dogs_120.jpg
# preprocessed: task2_data/dogs//dogs_121.jpg
# preprocessed: task2_data/dogs//dogs_122.jpg
# preprocessed: task2_data/dogs//dogs_123.jpg
# preprocessed: task2_data/dogs//dogs_124.jpg
# preprocessed: task2_data/dogs//dogs_125.jpg
# preprocessed: task2_data/dogs//dogs_126.jpg
# preprocessed: task2_data/dogs//dogs_127.jpg
# preprocessed: task2_data/dogs//dogs_128.jpg
# preprocessed: task2_data/dogs//dogs_129.jpg
# preprocessed: task2_data/dogs//dogs_13.jpg
# preprocessed: task2_data/dogs//dogs_130.jpg
# preprocessed: task2_data/dogs//dogs_131.jpg
# preprocessed: task2_data/dogs//dogs_132.jpg
# preprocessed: task2_data/dogs//dogs_133.jpg
# preprocessed: task2_data/dogs//dogs_134.jpg
# preprocessed: task2_data/dogs//dogs_135.jpg
# preprocessed: task2_data/dogs//dogs_136.jpg
# preprocessed: task2_data/dogs//dogs_137.jpg
# preprocessed: task2_data/dogs//dogs_138.jpg
# preprocessed: task2_data/dogs//dogs_139.jpg
# preprocessed: task2_data/dogs//dogs_14.jpg
# preprocessed: task2_data/dogs//dogs_140.jpg
# preprocessed: task2_data/dogs//dogs_141.jpg
# preprocessed: task2_data/dogs//dogs_142.jpg
# preprocessed: task2_data/dogs//dogs_143.jpg
# preprocessed: task2_data/dogs//dogs_144.jpg
# preprocessed: task2_data/dogs//dogs_145.jpg
# preprocessed: task2_data/dogs//dogs_146.jpg
# preprocessed: task2_data/dogs//dogs_147.jpg
# preprocessed: task2_data/dogs//dogs_148.jpg
# preprocessed: task2_data/dogs//dogs_149.jpg
# preprocessed: task2_data/dogs//dogs_15.jpg
# preprocessed: task2_data/dogs//dogs_150.jpg
# preprocessed: task2_data/dogs//dogs_151.jpg
# preprocessed: task2_data/dogs//dogs_152.jpg
# preprocessed: task2_data/dogs//dogs_153.jpg
# preprocessed: task2_data/dogs//dogs_154.jpg
# preprocessed: task2_data/dogs//dogs_155.jpg
# preprocessed: task2_data/dogs//dogs_156.jpg
# preprocessed: task2_data/dogs//dogs_157.jpg
# preprocessed: task2_data/dogs//dogs_158.jpg
# preprocessed: task2_data/dogs//dogs_159.jpg
# preprocessed: task2_data/dogs//dogs_16.jpg
# preprocessed: task2_data/dogs//dogs_160.jpg
# preprocessed: task2_data/dogs//dogs_161.jpg
# preprocessed: task2_data/dogs//dogs_162.jpg
# preprocessed: task2_data/dogs//dogs_163.jpg
# preprocessed: task2_data/dogs//dogs_164.jpg
# preprocessed: task2_data/dogs//dogs_165.jpg
# preprocessed: task2_data/dogs//dogs_166.jpg
# preprocessed: task2_data/dogs//dogs_167.jpg
# preprocessed: task2_data/dogs//dogs_168.jpg
# preprocessed: task2_data/dogs//dogs_169.jpg
# preprocessed: task2_data/dogs//dogs_17.jpg
# preprocessed: task2_data/dogs//dogs_170.jpg
# preprocessed: task2_data/dogs//dogs_171.jpg
# preprocessed: task2_data/dogs//dogs_172.jpg
# preprocessed: task2_data/dogs//dogs_173.jpg
# preprocessed: task2_data/dogs//dogs_174.jpg
# preprocessed: task2_data/dogs//dogs_175.jpg
# preprocessed: task2_data/dogs//dogs_176.jpg
# preprocessed: task2_data/dogs//dogs_177.jpg
# preprocessed: task2_data/dogs//dogs_178.jpg
# preprocessed: task2_data/dogs//dogs_179.jpg
# preprocessed: task2_data/dogs//dogs_18.jpg
# preprocessed: task2_data/dogs//dogs_180.jpg
# preprocessed: task2_data/dogs//dogs_181.jpg
# preprocessed: task2_data/dogs//dogs_182.jpg
# preprocessed: task2_data/dogs//dogs_183.jpg
# preprocessed: task2_data/dogs//dogs_184.jpg
# preprocessed: task2_data/dogs//dogs_185.jpg
# preprocessed: task2_data/dogs//dogs_186.jpg
# preprocessed: task2_data/dogs//dogs_187.jpg
# preprocessed: task2_data/dogs//dogs_188.jpg
# preprocessed: task2_data/dogs//dogs_189.jpg
# preprocessed: task2_data/dogs//dogs_19.jpg
# preprocessed: task2_data/dogs//dogs_190.jpg
# preprocessed: task2_data/dogs//dogs_191.jpg
# preprocessed: task2_data/dogs//dogs_192.jpg
# preprocessed: task2_data/dogs//dogs_193.jpg
# preprocessed: task2_data/dogs//dogs_194.jpg
# preprocessed: task2_data/dogs//dogs_195.jpg
# preprocessed: task2_data/dogs//dogs_196.jpg
# preprocessed: task2_data/dogs//dogs_197.jpg
# preprocessed: task2_data/dogs//dogs_198.jpg
# preprocessed: task2_data/dogs//dogs_199.jpg
# preprocessed: task2_data/dogs//dogs_2.jpg
# preprocessed: task2_data/dogs//dogs_20.jpg
# preprocessed: task2_data/dogs//dogs_200.jpg
# preprocessed: task2_data/dogs//dogs_201.jpg
# preprocessed: task2_data/dogs//dogs_202.jpg
# preprocessed: task2_data/dogs//dogs_203.jpg
# preprocessed: task2_data/dogs//dogs_204.jpg
# preprocessed: task2_data/dogs//dogs_205.jpg
# preprocessed: task2_data/dogs//dogs_206.jpg
# preprocessed: task2_data/dogs//dogs_207.jpg
# preprocessed: task2_data/dogs//dogs_208.jpg
# preprocessed: task2_data/dogs//dogs_209.jpg
# preprocessed: task2_data/dogs//dogs_21.jpg
# preprocessed: task2_data/dogs//dogs_210.jpg
# preprocessed: task2_data/dogs//dogs_211.jpg
# preprocessed: task2_data/dogs//dogs_212.jpg
# preprocessed: task2_data/dogs//dogs_213.jpg
# preprocessed: task2_data/dogs//dogs_214.jpg
# preprocessed: task2_data/dogs//dogs_215.jpg
# preprocessed: task2_data/dogs//dogs_216.jpg
# preprocessed: task2_data/dogs//dogs_217.jpg
# preprocessed: task2_data/dogs//dogs_218.jpg
# preprocessed: task2_data/dogs//dogs_219.jpg
# preprocessed: task2_data/dogs//dogs_22.jpg
# preprocessed: task2_data/dogs//dogs_220.jpg
# preprocessed: task2_data/dogs//dogs_221.jpg
# preprocessed: task2_data/dogs//dogs_222.jpg
# preprocessed: task2_data/dogs//dogs_223.jpg
# preprocessed: task2_data/dogs//dogs_224.jpg
# preprocessed: task2_data/dogs//dogs_225.jpg
# preprocessed: task2_data/dogs//dogs_226.jpg
# preprocessed: task2_data/dogs//dogs_227.jpg
# preprocessed: task2_data/dogs//dogs_228.jpg
# preprocessed: task2_data/dogs//dogs_229.jpg
# preprocessed: task2_data/dogs//dogs_23.jpg
# preprocessed: task2_data/dogs//dogs_230.jpg
# preprocessed: task2_data/dogs//dogs_231.jpg
# preprocessed: task2_data/dogs//dogs_232.jpg
# preprocessed: task2_data/dogs//dogs_233.jpg
# preprocessed: task2_data/dogs//dogs_234.jpg
# preprocessed: task2_data/dogs//dogs_235.jpg
# preprocessed: task2_data/dogs//dogs_236.jpg
# preprocessed: task2_data/dogs//dogs_237.jpg
# preprocessed: task2_data/dogs//dogs_238.jpg
# preprocessed: task2_data/dogs//dogs_239.jpg
# preprocessed: task2_data/dogs//dogs_24.jpg
# preprocessed: task2_data/dogs//dogs_240.jpg
# preprocessed: task2_data/dogs//dogs_241.jpg
# preprocessed: task2_data/dogs//dogs_242.jpg
# preprocessed: task2_data/dogs//dogs_243.jpg
# preprocessed: task2_data/dogs//dogs_244.jpg
# preprocessed: task2_data/dogs//dogs_245.jpg
# preprocessed: task2_data/dogs//dogs_246.jpg
# preprocessed: task2_data/dogs//dogs_247.jpg
# preprocessed: task2_data/dogs//dogs_248.jpg
# preprocessed: task2_data/dogs//dogs_249.jpg
# preprocessed: task2_data/dogs//dogs_25.jpg
# preprocessed: task2_data/dogs//dogs_250.jpg
# preprocessed: task2_data/dogs//dogs_251.jpg
# preprocessed: task2_data/dogs//dogs_252.jpg
# preprocessed: task2_data/dogs//dogs_253.jpg
# preprocessed: task2_data/dogs//dogs_254.jpg
# preprocessed: task2_data/dogs//dogs_255.jpg
# preprocessed: task2_data/dogs//dogs_256.jpg
# preprocessed: task2_data/dogs//dogs_257.jpg
# preprocessed: task2_data/dogs//dogs_258.jpg
# preprocessed: task2_data/dogs//dogs_259.jpg
# preprocessed: task2_data/dogs//dogs_26.jpg
# preprocessed: task2_data/dogs//dogs_260.jpg
# preprocessed: task2_data/dogs//dogs_261.jpg
# preprocessed: task2_data/dogs//dogs_262.jpg
# preprocessed: task2_data/dogs//dogs_263.jpg
# preprocessed: task2_data/dogs//dogs_264.jpg
# preprocessed: task2_data/dogs//dogs_265.jpg
# preprocessed: task2_data/dogs//dogs_266.jpg
# preprocessed: task2_data/dogs//dogs_267.jpg
# preprocessed: task2_data/dogs//dogs_268.jpg
# preprocessed: task2_data/dogs//dogs_269.jpg
# preprocessed: task2_data/dogs//dogs_27.jpg
# preprocessed: task2_data/dogs//dogs_270.jpg
# preprocessed: task2_data/dogs//dogs_271.jpg
# preprocessed: task2_data/dogs//dogs_272.jpg
# preprocessed: task2_data/dogs//dogs_273.jpg
# preprocessed: task2_data/dogs//dogs_274.jpg
# preprocessed: task2_data/dogs//dogs_275.jpg
# preprocessed: task2_data/dogs//dogs_276.jpg
# preprocessed: task2_data/dogs//dogs_277.jpg
# preprocessed: task2_data/dogs//dogs_278.jpg
# preprocessed: task2_data/dogs//dogs_279.jpg
# preprocessed: task2_data/dogs//dogs_28.jpg
# preprocessed: task2_data/dogs//dogs_280.jpg
# preprocessed: task2_data/dogs//dogs_281.jpg
# preprocessed: task2_data/dogs//dogs_282.jpg
# preprocessed: task2_data/dogs//dogs_283.jpg
# preprocessed: task2_data/dogs//dogs_284.jpg
# preprocessed: task2_data/dogs//dogs_285.jpg
# preprocessed: task2_data/dogs//dogs_286.jpg
# preprocessed: task2_data/dogs//dogs_287.jpg
# preprocessed: task2_data/dogs//dogs_288.jpg
# preprocessed: task2_data/dogs//dogs_289.jpg
# preprocessed: task2_data/dogs//dogs_29.jpg
# preprocessed: task2_data/dogs//dogs_290.jpg
# preprocessed: task2_data/dogs//dogs_291.jpg
# preprocessed: task2_data/dogs//dogs_292.jpg
# preprocessed: task2_data/dogs//dogs_293.jpg
# preprocessed: task2_data/dogs//dogs_294.jpg
# preprocessed: task2_data/dogs//dogs_295.jpg
# preprocessed: task2_data/dogs//dogs_296.jpg
# preprocessed: task2_data/dogs//dogs_297.jpg
# preprocessed: task2_data/dogs//dogs_298.jpg
# preprocessed: task2_data/dogs//dogs_299.jpg
# preprocessed: task2_data/dogs//dogs_3.jpg
# preprocessed: task2_data/dogs//dogs_30.jpg
# preprocessed: task2_data/dogs//dogs_300.jpg
# preprocessed: task2_data/dogs//dogs_31.jpg
# preprocessed: task2_data/dogs//dogs_32.jpg
# preprocessed: task2_data/dogs//dogs_33.jpg
# preprocessed: task2_data/dogs//dogs_34.jpg
# preprocessed: task2_data/dogs//dogs_35.jpg
# preprocessed: task2_data/dogs//dogs_36.jpg
# preprocessed: task2_data/dogs//dogs_37.jpg
# preprocessed: task2_data/dogs//dogs_38.jpg
# preprocessed: task2_data/dogs//dogs_39.jpg
# preprocessed: task2_data/dogs//dogs_4.jpg
# preprocessed: task2_data/dogs//dogs_40.jpg
# preprocessed: task2_data/dogs//dogs_41.jpg
# preprocessed: task2_data/dogs//dogs_42.jpg
# preprocessed: task2_data/dogs//dogs_43.jpg
# preprocessed: task2_data/dogs//dogs_44.jpg
# preprocessed: task2_data/dogs//dogs_45.jpg
# preprocessed: task2_data/dogs//dogs_46.jpg
# preprocessed: task2_data/dogs//dogs_47.jpg
# preprocessed: task2_data/dogs//dogs_48.jpg
# preprocessed: task2_data/dogs//dogs_49.jpg
# preprocessed: task2_data/dogs//dogs_5.jpg
# preprocessed: task2_data/dogs//dogs_50.jpg
# preprocessed: task2_data/dogs//dogs_51.jpg
# preprocessed: task2_data/dogs//dogs_52.jpg
# preprocessed: task2_data/dogs//dogs_53.jpg
# preprocessed: task2_data/dogs//dogs_54.jpg
# preprocessed: task2_data/dogs//dogs_55.jpg
# preprocessed: task2_data/dogs//dogs_56.jpg
# preprocessed: task2_data/dogs//dogs_57.jpg
# preprocessed: task2_data/dogs//dogs_58.jpg
# preprocessed: task2_data/dogs//dogs_59.jpg
# preprocessed: task2_data/dogs//dogs_6.jpg
# preprocessed: task2_data/dogs//dogs_60.jpg
# preprocessed: task2_data/dogs//dogs_61.jpg
# preprocessed: task2_data/dogs//dogs_62.jpg
# preprocessed: task2_data/dogs//dogs_63.jpg
# preprocessed: task2_data/dogs//dogs_64.jpg
# preprocessed: task2_data/dogs//dogs_65.jpg
# preprocessed: task2_data/dogs//dogs_66.jpg
# preprocessed: task2_data/dogs//dogs_67.jpg
# preprocessed: task2_data/dogs//dogs_68.jpg
# preprocessed: task2_data/dogs//dogs_69.jpg
# preprocessed: task2_data/dogs//dogs_7.jpg
# preprocessed: task2_data/dogs//dogs_70.jpg
# preprocessed: task2_data/dogs//dogs_71.jpg
# preprocessed: task2_data/dogs//dogs_72.jpg
# preprocessed: task2_data/dogs//dogs_73.jpg
# preprocessed: task2_data/dogs//dogs_74.jpg
# preprocessed: task2_data/dogs//dogs_75.jpg
# preprocessed: task2_data/dogs//dogs_76.jpg
# preprocessed: task2_data/dogs//dogs_77.jpg
# preprocessed: task2_data/dogs//dogs_78.jpg
# preprocessed: task2_data/dogs//dogs_79.jpg
# preprocessed: task2_data/dogs//dogs_8.jpg
# preprocessed: task2_data/dogs//dogs_80.jpg
# preprocessed: task2_data/dogs//dogs_81.jpg
# preprocessed: task2_data/dogs//dogs_82.jpg
# preprocessed: task2_data/dogs//dogs_83.jpg
# preprocessed: task2_data/dogs//dogs_84.jpg
# preprocessed: task2_data/dogs//dogs_85.jpg
# preprocessed: task2_data/dogs//dogs_86.jpg
# preprocessed: task2_data/dogs//dogs_87.jpg
# preprocessed: task2_data/dogs//dogs_88.jpg
# preprocessed: task2_data/dogs//dogs_89.jpg
# preprocessed: task2_data/dogs//dogs_9.jpg
# preprocessed: task2_data/dogs//dogs_90.jpg
# preprocessed: task2_data/dogs//dogs_91.jpg
# preprocessed: task2_data/dogs//dogs_92.jpg
# preprocessed: task2_data/dogs//dogs_93.jpg
# preprocessed: task2_data/dogs//dogs_94.jpg
# preprocessed: task2_data/dogs//dogs_95.jpg
# preprocessed: task2_data/dogs//dogs_96.jpg
# preprocessed: task2_data/dogs//dogs_97.jpg
# preprocessed: task2_data/dogs//dogs_98.jpg
# preprocessed: task2_data/dogs//dogs_99.jpg
# (300, 25088) (300, 25088)
# (600, 25088) (600, 1)

# %%
print(X.shape)
# Out:
# (600, 25088)

# %%
#数据分离
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape,X_test.shape,X.shape)
# Out:
# (480, 25088) (120, 25088) (600, 25088)

# %%
#建立mlp模型
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
#隐藏层
model.add(Dense(units=10,activation='relu',input_dim=25088))
#输出层
model.add(Dense(units=1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                250890
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 250,901
# Trainable params: 250,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
#模型求解参数配置
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#模型训练
model.fit(X_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 9s 3ms/step - loss: 2.4850 - accuracy: 0.7496
# Epoch 2/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9796
# Epoch 3/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9905
# Epoch 4/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9968
# Epoch 5/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0201 - accuracy: 0.9945
# Epoch 6/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 0.9932
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9925
# Epoch 8/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9951
# Epoch 9/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9954
# Epoch 10/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 0.9989
# Epoch 11/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 12/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 13/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9964
# Epoch 14/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 15/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 16/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 17/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 18/50
# 15/15 [==============================] - 0s 3ms/step - loss: 7.3182e-04 - accuracy: 0.9997
# Epoch 19/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 20/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 21/50
# 15/15 [==============================] - 0s 3ms/step - loss: 6.6111e-04 - accuracy: 1.0000
# Epoch 22/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 23/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 24/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 25/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 26/50
# 15/15 [==============================] - 0s 3ms/step - loss: 6.4496e-04 - accuracy: 1.0000
# Epoch 27/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 28/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 29/50
# 15/15 [==============================] - 0s 3ms/step - loss: 7.5164e-04 - accuracy: 1.0000
# Epoch 30/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 31/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 32/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 33/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 34/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 35/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 36/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 37/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 38/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 39/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 40/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 41/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 42/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 43/50
# 15/15 [==============================] - 0s 3ms/step - loss: 3.4762e-04 - accuracy: 1.0000
# Epoch 44/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 45/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 46/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 47/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 48/50
# 15/15 [==============================] - 0s 3ms/step - loss: 5.3802e-04 - accuracy: 1.0000
# Epoch 49/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 50/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000

# %%
from sklearn.metrics import accuracy_score
y_train_predict = model.predict_classes(X_train)
accuracy_train = accuracy_score(y_train,y_train_predict)
print(accuracy_train)
# Out:
# 1.0
# C:\Users\zheng\AppData\Roaming\Python\Python38\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#测试数据预测准确率
y_test_predict = model.predict_classes(X_test)
accuracy_test = accuracy_score(y_test,y_test_predict)
print(accuracy_test)
# Out:
# 0.9916666666666667
# C:\Users\zheng\AppData\Roaming\Python\Python38\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#图片加载》图片格式转化》数据预处理》vgg16特征信息提取》模型预测
pic1 = '1.png'
pic1 = load_img(pic1,target_size=(224,224))
pic1_array = img_to_array(pic1)
pic1_array = np.expand_dims(pic1_array,axis=0)
pic1_array = preprocess_input(pic1_array)
pic1_features = model_vgg.predict(pic1_array)
pic1_features= pic1_features.reshape(1,7*7*512)
#mlp模型预测
result = model.predict_classes(pic1_features)
#1:dog； 0：cat
print('dog' if result==1 else 'cat')
# Out:
# dog
# C:\Users\zheng\AppData\Roaming\Python\Python38\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
fig3 = plt.figure()
plt.imshow(pic1)

# %%
#本地九张图片处理
a = [i for i in range(1,10)]
fig3 = plt.figure(figsize=(10,10))
for i in a:
    img_name = str(i)+'.png'
    
    
    pic1 = img_name
    pic1 = load_img(pic1,target_size=(224,224))
    pic1_array = img_to_array(pic1)
    pic1_array = np.expand_dims(pic1_array,axis=0)
    pic1_array = preprocess_input(pic1_array)
    pic1_features = model_vgg.predict(pic1_array)
    pic1_features= pic1_features.reshape(1,7*7*512)
    #mlp模型预测
    result = model.predict_classes(pic1_features)
    #1:dog； 0：cat
#     print('dog' if result==1 else 'cat')
    
    plt.subplot(3,3,i)
    plt.imshow(pic1)
    plt.title('predict result: dog' if result==1 else 'predict reuslt:cat')
